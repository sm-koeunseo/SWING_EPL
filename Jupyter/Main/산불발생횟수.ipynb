# %%
import pandas as pd
df = pd.read_csv('산불발생횟수.csv', encoding = 'cp949')

# %%
df_ingu = pd.read_csv('인구밀도.csv', encoding = 'cp949')

# %%
seoul22 = df[(df['연도'] == 2022) & (df['시도'] == '서울')].shape[0]
busan22 = df[(df['연도'] == 2022) & (df['시도'] == '부산')].shape[0]
daegu22 = df[(df['연도'] == 2022) & (df['시도'] == '대구')].shape[0]
gwangju22 = df[(df['연도'] == 2022) & (df['시도'] == '광주')].shape[0]
incheon22 = df[(df['연도'] == 2022) & (df['시도'] == '인천')].shape[0]
daejeon22 = df[(df['연도'] == 2022) & (df['시도'] == '대전')].shape[0]
ulsan22 = df[(df['연도'] == 2022) & (df['시도'] == '울산')].shape[0]
sejong22 = df[(df['연도'] == 2022) & (df['시도'] == '세종')].shape[0]
gyeonggi22 = df[(df['연도'] == 2022) & (df['시도'] == '경기')].shape[0]
gangwon22 = df[(df['연도'] == 2022) & (df['시도'] == '강원')].shape[0]
chungbuk22 = df[(df['연도'] == 2022) & (df['시도'] == '충북')].shape[0]
chungnam22 = df[(df['연도'] == 2022) & (df['시도'] == '충남')].shape[0]
jeonbuk22 = df[(df['연도'] == 2022) & (df['시도'] == '전북')].shape[0]
jeonnam22 = df[(df['연도'] == 2022) & (df['시도'] == '전남')].shape[0]
gyeongbuk22 = df[(df['연도'] == 2022) & (df['시도'] == '경북')].shape[0]
gyeongnam22 = df[(df['연도'] == 2022) & (df['시도'] == '경남')].shape[0]

# %%
seoul21 = df[(df['연도'] == 2021) & (df['시도'] == '서울')].shape[0]
busan21 = df[(df['연도'] == 2021) & (df['시도'] == '부산')].shape[0]
daegu21 = df[(df['연도'] == 2021) & (df['시도'] == '대구')].shape[0]
gwangju21 = df[(df['연도'] == 2021) & (df['시도'] == '광주')].shape[0]
incheon21 = df[(df['연도'] == 2021) & (df['시도'] == '인천')].shape[0]
daejeon21 = df[(df['연도'] == 2021) & (df['시도'] == '대전')].shape[0]
ulsan21 = df[(df['연도'] == 2021) & (df['시도'] == '울산')].shape[0]
sejong21 = df[(df['연도'] == 2021) & (df['시도'] == '세종')].shape[0]
gyeonggi21 = df[(df['연도'] == 2021) & (df['시도'] == '경기')].shape[0]
gangwon21 = df[(df['연도'] == 2021) & (df['시도'] == '강원')].shape[0]
chungbuk21 = df[(df['연도'] == 2021) & (df['시도'] == '충북')].shape[0]
chungnam21 = df[(df['연도'] == 2021) & (df['시도'] == '충남')].shape[0]
jeonbuk21 = df[(df['연도'] == 2021) & (df['시도'] == '전북')].shape[0]
jeonnam21 = df[(df['연도'] == 2021) & (df['시도'] == '전남')].shape[0]
gyeongbuk21 = df[(df['연도'] == 2021) & (df['시도'] == '경북')].shape[0]
gyeongnam21 = df[(df['연도'] == 2021) & (df['시도'] == '경남')].shape[0]

# %%
seoul20 = df[(df['연도'] == 2020) & (df['시도'] == '서울')].shape[0]
busan20 = df[(df['연도'] == 2020) & (df['시도'] == '부산')].shape[0]
daegu20 = df[(df['연도'] == 2020) & (df['시도'] == '대구')].shape[0]
gwangju20 = df[(df['연도'] == 2020) & (df['시도'] == '광주')].shape[0]
incheon20 = df[(df['연도'] == 2020) & (df['시도'] == '인천')].shape[0]
daejeon20 = df[(df['연도'] == 2020) & (df['시도'] == '대전')].shape[0]
ulsan20 = df[(df['연도'] == 2020) & (df['시도'] == '울산')].shape[0]
sejong20 = df[(df['연도'] == 2020) & (df['시도'] == '세종')].shape[0]
gyeonggi20 = df[(df['연도'] == 2020) & (df['시도'] == '경기')].shape[0]
gangwon20 = df[(df['연도'] == 2020) & (df['시도'] == '강원')].shape[0]
chungbuk20 = df[(df['연도'] == 2020) & (df['시도'] == '충북')].shape[0]
chungnam20 = df[(df['연도'] == 2020) & (df['시도'] == '충남')].shape[0]
jeonbuk20 = df[(df['연도'] == 2020) & (df['시도'] == '전북')].shape[0]
jeonnam20 = df[(df['연도'] == 2020) & (df['시도'] == '전남')].shape[0]
gyeongbuk20 = df[(df['연도'] == 2020) & (df['시도'] == '경북')].shape[0]
gyeongnam20 = df[(df['연도'] == 2020) & (df['시도'] == '경남')].shape[0]

# %%
seoul19 = df[(df['연도'] == 2019) & (df['시도'] == '서울')].shape[0]
busan19 = df[(df['연도'] == 2019) & (df['시도'] == '부산')].shape[0]
daegu19 = df[(df['연도'] == 2019) & (df['시도'] == '대구')].shape[0]
gwangju19 = df[(df['연도'] == 2019) & (df['시도'] == '광주')].shape[0]
incheon19 = df[(df['연도'] == 2019) & (df['시도'] == '인천')].shape[0]
daejeon19 = df[(df['연도'] == 2019) & (df['시도'] == '대전')].shape[0]
ulsan19 = df[(df['연도'] == 2019) & (df['시도'] == '울산')].shape[0]
sejong19 = df[(df['연도'] == 2019) & (df['시도'] == '세종')].shape[0]
gyeonggi19 = df[(df['연도'] == 2019) & (df['시도'] == '경기')].shape[0]
gangwon19 = df[(df['연도'] == 2019) & (df['시도'] == '강원')].shape[0]
chungbuk19 = df[(df['연도'] == 2019) & (df['시도'] == '충북')].shape[0]
chungnam19 = df[(df['연도'] == 2019) & (df['시도'] == '충남')].shape[0]
jeonbuk19 = df[(df['연도'] == 2019) & (df['시도'] == '전북')].shape[0]
jeonnam19 = df[(df['연도'] == 2019) & (df['시도'] == '전남')].shape[0]
gyeongbuk19 = df[(df['연도'] == 2019) & (df['시도'] == '경북')].shape[0]
gyeongnam19 = df[(df['연도'] == 2019) & (df['시도'] == '경남')].shape[0]

# %%
seoul18 = df[(df['연도'] == 2018) & (df['시도'] == '서울')].shape[0]
busan18 = df[(df['연도'] == 2018) & (df['시도'] == '부산')].shape[0]
daegu18 = df[(df['연도'] == 2018) & (df['시도'] == '대구')].shape[0]
gwangju18 = df[(df['연도'] == 2018) & (df['시도'] == '광주')].shape[0]
incheon18 = df[(df['연도'] == 2018) & (df['시도'] == '인천')].shape[0]
daejeon18 = df[(df['연도'] == 2018) & (df['시도'] == '대전')].shape[0]
ulsan18 = df[(df['연도'] == 2018) & (df['시도'] == '울산')].shape[0]
sejong18 = df[(df['연도'] == 2018) & (df['시도'] == '세종')].shape[0]
gyeonggi18 = df[(df['연도'] == 2018) & (df['시도'] == '경기')].shape[0]
gangwon18 = df[(df['연도'] == 2018) & (df['시도'] == '강원')].shape[0]
chungbuk18 = df[(df['연도'] == 2018) & (df['시도'] == '충북')].shape[0]
chungnam18 = df[(df['연도'] == 2018) & (df['시도'] == '충남')].shape[0]
jeonbuk18 = df[(df['연도'] == 2018) & (df['시도'] == '전북')].shape[0]
jeonnam18 = df[(df['연도'] == 2018) & (df['시도'] == '전남')].shape[0]
gyeongbuk18 = df[(df['연도'] == 2018) & (df['시도'] == '경북')].shape[0]
gyeongnam18 = df[(df['연도'] == 2018) & (df['시도'] == '경남')].shape[0]

# %%
seoul17 = df[(df['연도'] == 2017) & (df['시도'] == '서울')].shape[0]
busan17 = df[(df['연도'] == 2017) & (df['시도'] == '부산')].shape[0]
daegu17 = df[(df['연도'] == 2017) & (df['시도'] == '대구')].shape[0]
gwangju17 = df[(df['연도'] == 2017) & (df['시도'] == '광주')].shape[0]
incheon17 = df[(df['연도'] == 2017) & (df['시도'] == '인천')].shape[0]
daejeon17 = df[(df['연도'] == 2017) & (df['시도'] == '대전')].shape[0]
ulsan17 = df[(df['연도'] == 2017) & (df['시도'] == '울산')].shape[0]
sejong17 = df[(df['연도'] == 2017) & (df['시도'] == '세종')].shape[0]
gyeonggi17 = df[(df['연도'] == 2017) & (df['시도'] == '경기')].shape[0]
gangwon17 = df[(df['연도'] == 2017) & (df['시도'] == '강원')].shape[0]
chungbuk17 = df[(df['연도'] == 2017) & (df['시도'] == '충북')].shape[0]
chungnam17 = df[(df['연도'] == 2017) & (df['시도'] == '충남')].shape[0]
jeonbuk17 = df[(df['연도'] == 2017) & (df['시도'] == '전북')].shape[0]
jeonnam17 = df[(df['연도'] == 2017) & (df['시도'] == '전남')].shape[0]
gyeongbuk17 = df[(df['연도'] == 2017) & (df['시도'] == '경북')].shape[0]
gyeongnam17 = df[(df['연도'] == 2017) & (df['시도'] == '경남')].shape[0]

# %%
seoul16 = df[(df['연도'] == 2016) & (df['시도'] == '서울')].shape[0]
busan16 = df[(df['연도'] == 2016) & (df['시도'] == '부산')].shape[0]
daegu16 = df[(df['연도'] == 2016) & (df['시도'] == '대구')].shape[0]
gwangju16 = df[(df['연도'] == 2016) & (df['시도'] == '광주')].shape[0]
incheon16 = df[(df['연도'] == 2016) & (df['시도'] == '인천')].shape[0]
daejeon16 = df[(df['연도'] == 2016) & (df['시도'] == '대전')].shape[0]
ulsan16 = df[(df['연도'] == 2016) & (df['시도'] == '울산')].shape[0]
sejong16 = df[(df['연도'] == 2016) & (df['시도'] == '세종')].shape[0]
gyeonggi16 = df[(df['연도'] == 2016) & (df['시도'] == '경기')].shape[0]
gangwon16 = df[(df['연도'] == 2016) & (df['시도'] == '강원')].shape[0]
chungbuk16 = df[(df['연도'] == 2016) & (df['시도'] == '충북')].shape[0]
chungnam16 = df[(df['연도'] == 2016) & (df['시도'] == '충남')].shape[0]
jeonbuk16 = df[(df['연도'] == 2016) & (df['시도'] == '전북')].shape[0]
jeonnam16 = df[(df['연도'] == 2016) & (df['시도'] == '전남')].shape[0]
gyeongbuk16 = df[(df['연도'] == 2016) & (df['시도'] == '경북')].shape[0]
gyeongnam16 = df[(df['연도'] == 2016) & (df['시도'] == '경남')].shape[0]

# %%
seoul15 = df[(df['연도'] == 2015) & (df['시도'] == '서울')].shape[0]
busan15 = df[(df['연도'] == 2015) & (df['시도'] == '부산')].shape[0]
daegu15 = df[(df['연도'] == 2015) & (df['시도'] == '대구')].shape[0]
gwangju15 = df[(df['연도'] == 2015) & (df['시도'] == '광주')].shape[0]
incheon15 = df[(df['연도'] == 2015) & (df['시도'] == '인천')].shape[0]
daejeon15 = df[(df['연도'] == 2015) & (df['시도'] == '대전')].shape[0]
ulsan15 = df[(df['연도'] == 2015) & (df['시도'] == '울산')].shape[0]
sejong15 = df[(df['연도'] == 2015) & (df['시도'] == '세종')].shape[0]
gyeonggi15 = df[(df['연도'] == 2015) & (df['시도'] == '경기')].shape[0]
gangwon15 = df[(df['연도'] == 2015) & (df['시도'] == '강원')].shape[0]
chungbuk15 = df[(df['연도'] == 2015) & (df['시도'] == '충북')].shape[0]
chungnam15 = df[(df['연도'] == 2015) & (df['시도'] == '충남')].shape[0]
jeonbuk15 = df[(df['연도'] == 2015) & (df['시도'] == '전북')].shape[0]
jeonnam15 = df[(df['연도'] == 2015) & (df['시도'] == '전남')].shape[0]
gyeongbuk15 = df[(df['연도'] == 2015) & (df['시도'] == '경북')].shape[0]
gyeongnam15 = df[(df['연도'] == 2015) & (df['시도'] == '경남')].shape[0]

# %%
seoul14 = df[(df['연도'] == 2014) & (df['시도'] == '서울')].shape[0]
busan14 = df[(df['연도'] == 2014) & (df['시도'] == '부산')].shape[0]
daegu14 = df[(df['연도'] == 2014) & (df['시도'] == '대구')].shape[0]
gwangju14 = df[(df['연도'] == 2014) & (df['시도'] == '광주')].shape[0]
incheon14 = df[(df['연도'] == 2014) & (df['시도'] == '인천')].shape[0]
daejeon14 = df[(df['연도'] == 2014) & (df['시도'] == '대전')].shape[0]
ulsan14 = df[(df['연도'] == 2014) & (df['시도'] == '울산')].shape[0]
sejong14 = df[(df['연도'] == 2014) & (df['시도'] == '세종')].shape[0]
gyeonggi14 = df[(df['연도'] == 2014) & (df['시도'] == '경기')].shape[0]
gangwon14 = df[(df['연도'] == 2014) & (df['시도'] == '강원')].shape[0]
chungbuk14 = df[(df['연도'] == 2014) & (df['시도'] == '충북')].shape[0]
chungnam14 = df[(df['연도'] == 2014) & (df['시도'] == '충남')].shape[0]
jeonbuk14 = df[(df['연도'] == 2014) & (df['시도'] == '전북')].shape[0]
jeonnam14 = df[(df['연도'] == 2014) & (df['시도'] == '전남')].shape[0]
gyeongbuk14 = df[(df['연도'] == 2014) & (df['시도'] == '경북')].shape[0]
gyeongnam14 = df[(df['연도'] == 2014) & (df['시도'] == '경남')].shape[0]

# %%
seoul13 = df[(df['연도'] == 2013) & (df['시도'] == '서울')].shape[0]
busan13 = df[(df['연도'] == 2013) & (df['시도'] == '부산')].shape[0]
daegu13 = df[(df['연도'] == 2013) & (df['시도'] == '대구')].shape[0]
gwangju13 = df[(df['연도'] == 2013) & (df['시도'] == '광주')].shape[0]
incheon13 = df[(df['연도'] == 2013) & (df['시도'] == '인천')].shape[0]
daejeon13 = df[(df['연도'] == 2013) & (df['시도'] == '대전')].shape[0]
ulsan13 = df[(df['연도'] == 2013) & (df['시도'] == '울산')].shape[0]
sejong13 = df[(df['연도'] == 2013) & (df['시도'] == '세종')].shape[0]
gyeonggi13 = df[(df['연도'] == 2013) & (df['시도'] == '경기')].shape[0]
gangwon13 = df[(df['연도'] == 2013) & (df['시도'] == '강원')].shape[0]
chungbuk13 = df[(df['연도'] == 2013) & (df['시도'] == '충북')].shape[0]
chungnam13 = df[(df['연도'] == 2013) & (df['시도'] == '충남')].shape[0]
jeonbuk13 = df[(df['연도'] == 2013) & (df['시도'] == '전북')].shape[0]
jeonnam13 = df[(df['연도'] == 2013) & (df['시도'] == '전남')].shape[0]
gyeongbuk13 = df[(df['연도'] == 2013) & (df['시도'] == '경북')].shape[0]
gyeongnam13 = df[(df['연도'] == 2013) & (df['시도'] == '경남')].shape[0]

# %%
seoul = df[(df['시도'] == '서울')].shape[0]
busan = df[(df['시도'] == '부산')].shape[0]
daegu = df[(df['시도'] == '대구')].shape[0]
gwangju = df[(df['시도'] == '광주')].shape[0]
incheon = df[(df['시도'] == '인천')].shape[0]
daejeon = df[(df['시도'] == '대전')].shape[0]
ulsan = df[(df['시도'] == '울산')].shape[0]
sejong = df[(df['시도'] == '세종')].shape[0]
gyeonggi = df[(df['시도'] == '경기')].shape[0]
gangwon = df[(df['시도'] == '강원')].shape[0]
chungbuk = df[(df['시도'] == '충북')].shape[0]
chungnam = df[(df['시도'] == '충남')].shape[0]
jeonbuk = df[(df['시도'] == '전북')].shape[0]
jeonnam = df[(df['시도'] == '전남')].shape[0]
gyeongbuk = df[(df['시도'] == '경북')].shape[0]
gyeongnam = df[(df['시도'] == '경남')].shape[0]

print('서울:',seoul)
print('부산:',busan)
print('대구:',daegu)
print('광주:',gwangju)
print('인천:',incheon)
print('대전:',daejeon)
print('울산:',ulsan)
print('세종:',sejong)
print('경기:',gyeonggi)
print('강원:',gangwon)
print('충북:',chungbuk)
print('충남:',chungnam)
print('전북:',jeonbuk)
print('전남:',jeonnam)
print('경북:',gyeongbuk)
print('경남:',gyeongnam)
# Out:
# 서울: 112
# 부산: 139
# 대구: 104
# 광주: 34
# 인천: 189
# 대전: 72
# 울산: 133
# 세종: 36
# 경기: 1160
# 강원: 754
# 충북: 234
# 충남: 322
# 전북: 268
# 전남: 433
# 경북: 893
# 경남: 480

# %%
from matplotlib import pyplot as plt
import numpy as np

# %matplotlib inline
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 20
plt.rcParams["figure.figsize"] = (35, 15)

# %%
labels = ['seoul', 'busan', 'daegu', 'gwangju', 'incheon', 'daejeon', 'ulsan', 'sejong', 
          'gyeonggi', 'gangwon', 'chungbuk', 'chungnam', 'jeonbuk', 'jeonnam', 'gyeongbuk', 'gyeongnam']
data = [seoul, busan, daegu, gwangju, incheon, daejeon, ulsan, sejong, gyeonggi, 
        gangwon, chungbuk, chungnam, jeonbuk, jeonnam, gyeongbuk, gyeongnam]
plt.bar(labels, data)

plt.title('Number of Wildfires')
plt.xlabel('Region')
plt.ylabel('Number')

plt.show()

# %%
seoul_by_ingu13 = seoul13 / int(df_ingu.iloc[0,1].replace(',', ''))
seoul_by_ingu14 = seoul14 / int(df_ingu.iloc[0,2].replace(',', ''))
seoul_by_ingu15 = seoul15 / int(df_ingu.iloc[0,3].replace(',', ''))
seoul_by_ingu16 = seoul16 / int(df_ingu.iloc[0,4].replace(',', ''))
seoul_by_ingu17 = seoul17 / int(df_ingu.iloc[0,5].replace(',', ''))
seoul_by_ingu18 = seoul18 / int(df_ingu.iloc[0,6].replace(',', ''))
seoul_by_ingu19 = seoul19 / int(df_ingu.iloc[0,7].replace(',', ''))
seoul_by_ingu20 = seoul20 / int(df_ingu.iloc[0,8].replace(',', ''))
seoul_by_ingu21 = seoul21 / int(df_ingu.iloc[0,9].replace(',', ''))
seoul_by_ingu22 = seoul22 / int(df_ingu.iloc[0,10].replace(',', ''))

# %%
busan_by_ingu13 = busan13 / int(df_ingu.iloc[1,1].replace(',', ''))
busan_by_ingu14 = busan14 / int(df_ingu.iloc[1,2].replace(',', ''))
busan_by_ingu15 = busan15 / int(df_ingu.iloc[1,3].replace(',', ''))
busan_by_ingu16 = busan16 / int(df_ingu.iloc[1,4].replace(',', ''))
busan_by_ingu17 = busan17 / int(df_ingu.iloc[1,5].replace(',', ''))
busan_by_ingu18 = busan18 / int(df_ingu.iloc[1,6].replace(',', ''))
busan_by_ingu19 = busan19 / int(df_ingu.iloc[1,7].replace(',', ''))
busan_by_ingu20 = busan20 / int(df_ingu.iloc[1,8].replace(',', ''))
busan_by_ingu21 = busan21 / int(df_ingu.iloc[1,9].replace(',', ''))
busan_by_ingu22 = busan22 / int(df_ingu.iloc[1,10].replace(',', ''))

# %%
daegu_by_ingu13 = daegu13 / int(df_ingu.iloc[2,1].replace(',', ''))
daegu_by_ingu14 = daegu14 / int(df_ingu.iloc[2,2].replace(',', ''))
daegu_by_ingu15 = daegu15 / int(df_ingu.iloc[2,3].replace(',', ''))
daegu_by_ingu16 = daegu16 / int(df_ingu.iloc[2,4].replace(',', ''))
daegu_by_ingu17 = daegu17 / int(df_ingu.iloc[2,5].replace(',', ''))
daegu_by_ingu18 = daegu18 / int(df_ingu.iloc[2,6].replace(',', ''))
daegu_by_ingu19 = daegu19 / int(df_ingu.iloc[2,7].replace(',', ''))
daegu_by_ingu20 = daegu20 / int(df_ingu.iloc[2,8].replace(',', ''))
daegu_by_ingu21 = daegu21 / int(df_ingu.iloc[2,9].replace(',', ''))
daegu_by_ingu22 = daegu22 / int(df_ingu.iloc[2,10].replace(',', ''))

# %%
gwangju_by_ingu13 = gwangju13 / int(df_ingu.iloc[4,1].replace(',', ''))
gwangju_by_ingu14 = gwangju14 / int(df_ingu.iloc[4,2].replace(',', ''))
gwangju_by_ingu15 = gwangju15 / int(df_ingu.iloc[4,3].replace(',', ''))
gwangju_by_ingu16 = gwangju16 / int(df_ingu.iloc[4,4].replace(',', ''))
gwangju_by_ingu17 = gwangju17 / int(df_ingu.iloc[4,5].replace(',', ''))
gwangju_by_ingu18 = gwangju18 / int(df_ingu.iloc[4,6].replace(',', ''))
gwangju_by_ingu19 = gwangju19 / int(df_ingu.iloc[4,7].replace(',', ''))
gwangju_by_ingu20 = gwangju20 / int(df_ingu.iloc[4,8].replace(',', ''))
gwangju_by_ingu21 = gwangju21 / int(df_ingu.iloc[4,9].replace(',', ''))
gwangju_by_ingu22 = gwangju22 / int(df_ingu.iloc[4,10].replace(',', ''))

# %%
incheon_by_ingu13 = incheon13 / int(df_ingu.iloc[3,1].replace(',', ''))
incheon_by_ingu14 = incheon14 / int(df_ingu.iloc[3,2].replace(',', ''))
incheon_by_ingu15 = incheon15 / int(df_ingu.iloc[3,3].replace(',', ''))
incheon_by_ingu16 = incheon16 / int(df_ingu.iloc[3,4].replace(',', ''))
incheon_by_ingu17 = incheon17 / int(df_ingu.iloc[3,5].replace(',', ''))
incheon_by_ingu18 = incheon18 / int(df_ingu.iloc[3,6].replace(',', ''))
incheon_by_ingu19 = incheon19 / int(df_ingu.iloc[3,7].replace(',', ''))
incheon_by_ingu20 = incheon20 / int(df_ingu.iloc[3,8].replace(',', ''))
incheon_by_ingu21 = incheon21 / int(df_ingu.iloc[3,9].replace(',', ''))
incheon_by_ingu22 = incheon22 / int(df_ingu.iloc[3,10].replace(',', ''))

# %%
daejeon_by_ingu13 = daejeon13 / int(df_ingu.iloc[5,1].replace(',', ''))
daejeon_by_ingu14 = daejeon14 / int(df_ingu.iloc[5,2].replace(',', ''))
daejeon_by_ingu15 = daejeon15 / int(df_ingu.iloc[5,3].replace(',', ''))
daejeon_by_ingu16 = daejeon16 / int(df_ingu.iloc[5,4].replace(',', ''))
daejeon_by_ingu17 = daejeon17 / int(df_ingu.iloc[5,5].replace(',', ''))
daejeon_by_ingu18 = daejeon18 / int(df_ingu.iloc[5,6].replace(',', ''))
daejeon_by_ingu19 = daejeon19 / int(df_ingu.iloc[5,7].replace(',', ''))
daejeon_by_ingu20 = daejeon20 / int(df_ingu.iloc[5,8].replace(',', ''))
daejeon_by_ingu21 = daejeon21 / int(df_ingu.iloc[5,9].replace(',', ''))
daejeon_by_ingu22 = daejeon22 / int(df_ingu.iloc[5,10].replace(',', ''))

# %%
ulsan_by_ingu13 = ulsan13 / int(df_ingu.iloc[6,1].replace(',', ''))
ulsan_by_ingu14 = ulsan14 / int(df_ingu.iloc[6,2].replace(',', ''))
ulsan_by_ingu15 = ulsan15 / int(df_ingu.iloc[6,3].replace(',', ''))
ulsan_by_ingu16 = ulsan16 / int(df_ingu.iloc[6,4].replace(',', ''))
ulsan_by_ingu17 = ulsan17 / int(df_ingu.iloc[6,5].replace(',', ''))
ulsan_by_ingu18 = ulsan18 / int(df_ingu.iloc[6,6].replace(',', ''))
ulsan_by_ingu19 = ulsan19 / int(df_ingu.iloc[6,7].replace(',', ''))
ulsan_by_ingu20 = ulsan20 / int(df_ingu.iloc[6,8].replace(',', ''))
ulsan_by_ingu21 = ulsan21 / int(df_ingu.iloc[6,9].replace(',', ''))
ulsan_by_ingu22 = ulsan22 / int(df_ingu.iloc[6,10].replace(',', ''))

# %%
sejong_by_ingu13 = sejong13 / int(df_ingu.iloc[7,1].replace(',', ''))
sejong_by_ingu14 = sejong14 / int(df_ingu.iloc[7,2].replace(',', ''))
sejong_by_ingu15 = sejong15 / int(df_ingu.iloc[7,3].replace(',', ''))
sejong_by_ingu16 = sejong16 / int(df_ingu.iloc[7,4].replace(',', ''))
sejong_by_ingu17 = sejong17 / int(df_ingu.iloc[7,5].replace(',', ''))
sejong_by_ingu18 = sejong18 / int(df_ingu.iloc[7,6].replace(',', ''))
sejong_by_ingu19 = sejong19 / int(df_ingu.iloc[7,7].replace(',', ''))
sejong_by_ingu20 = sejong20 / int(df_ingu.iloc[7,8].replace(',', ''))
sejong_by_ingu21 = sejong21 / int(df_ingu.iloc[7,9].replace(',', ''))
sejong_by_ingu22 = sejong22 / int(df_ingu.iloc[7,10].replace(',', ''))

# %%
gyeonggi_by_ingu13 = gyeonggi13 / int(df_ingu.iloc[8,1].replace(',', ''))
gyeonggi_by_ingu14 = gyeonggi14 / int(df_ingu.iloc[8,2].replace(',', ''))
gyeonggi_by_ingu15 = gyeonggi15 / int(df_ingu.iloc[8,3].replace(',', ''))
gyeonggi_by_ingu16 = gyeonggi16 / int(df_ingu.iloc[8,4].replace(',', ''))
gyeonggi_by_ingu17 = gyeonggi17 / int(df_ingu.iloc[8,5].replace(',', ''))
gyeonggi_by_ingu18 = gyeonggi18 / int(df_ingu.iloc[8,6].replace(',', ''))
gyeonggi_by_ingu19 = gyeonggi19 / int(df_ingu.iloc[8,7].replace(',', ''))
gyeonggi_by_ingu20 = gyeonggi20 / int(df_ingu.iloc[8,8].replace(',', ''))
gyeonggi_by_ingu21 = gyeonggi21 / int(df_ingu.iloc[8,9].replace(',', ''))
gyeonggi_by_ingu22 = gyeonggi22 / int(df_ingu.iloc[8,10].replace(',', ''))

# %%
gangwon_by_ingu13 = gangwon13 / int(df_ingu.iloc[9,1].replace(',', ''))
gangwon_by_ingu14 = gangwon14 / int(df_ingu.iloc[9,2].replace(',', ''))
gangwon_by_ingu15 = gangwon15 / int(df_ingu.iloc[9,3].replace(',', ''))
gangwon_by_ingu16 = gangwon16 / int(df_ingu.iloc[9,4].replace(',', ''))
gangwon_by_ingu17 = gangwon17 / int(df_ingu.iloc[9,5].replace(',', ''))
gangwon_by_ingu18 = gangwon18 / int(df_ingu.iloc[9,6].replace(',', ''))
gangwon_by_ingu19 = gangwon19 / int(df_ingu.iloc[9,7].replace(',', ''))
gangwon_by_ingu20 = gangwon20 / int(df_ingu.iloc[9,8].replace(',', ''))
gangwon_by_ingu21 = gangwon21 / int(df_ingu.iloc[9,9].replace(',', ''))
gangwon_by_ingu22 = gangwon22 / int(df_ingu.iloc[9,10].replace(',', ''))

# %%
chungbuk_by_ingu13 = chungbuk13 / int(df_ingu.iloc[10,1].replace(',', ''))
chungbuk_by_ingu14 = chungbuk14 / int(df_ingu.iloc[10,2].replace(',', ''))
chungbuk_by_ingu15 = chungbuk15 / int(df_ingu.iloc[10,3].replace(',', ''))
chungbuk_by_ingu16 = chungbuk16 / int(df_ingu.iloc[10,4].replace(',', ''))
chungbuk_by_ingu17 = chungbuk17 / int(df_ingu.iloc[10,5].replace(',', ''))
chungbuk_by_ingu18 = chungbuk18 / int(df_ingu.iloc[10,6].replace(',', ''))
chungbuk_by_ingu19 = chungbuk19 / int(df_ingu.iloc[10,7].replace(',', ''))
chungbuk_by_ingu20 = chungbuk20 / int(df_ingu.iloc[10,8].replace(',', ''))
chungbuk_by_ingu21 = chungbuk21 / int(df_ingu.iloc[10,9].replace(',', ''))
chungbuk_by_ingu22 = chungbuk22 / int(df_ingu.iloc[10,10].replace(',', ''))

# %%
chungnam_by_ingu13 = chungnam13 / int(df_ingu.iloc[11,1].replace(',', ''))
chungnam_by_ingu14 = chungnam14 / int(df_ingu.iloc[11,2].replace(',', ''))
chungnam_by_ingu15 = chungnam15 / int(df_ingu.iloc[11,3].replace(',', ''))
chungnam_by_ingu16 = chungnam16 / int(df_ingu.iloc[11,4].replace(',', ''))
chungnam_by_ingu17 = chungnam17 / int(df_ingu.iloc[11,5].replace(',', ''))
chungnam_by_ingu18 = chungnam18 / int(df_ingu.iloc[11,6].replace(',', ''))
chungnam_by_ingu19 = chungnam19 / int(df_ingu.iloc[11,7].replace(',', ''))
chungnam_by_ingu20 = chungnam20 / int(df_ingu.iloc[11,8].replace(',', ''))
chungnam_by_ingu21 = chungnam21 / int(df_ingu.iloc[11,9].replace(',', ''))
chungnam_by_ingu22 = chungnam22 / int(df_ingu.iloc[11,10].replace(',', ''))

# %%
jeonbuk_by_ingu13 = jeonbuk13 / int(df_ingu.iloc[12,1].replace(',', ''))
jeonbuk_by_ingu14 = jeonbuk14 / int(df_ingu.iloc[12,2].replace(',', ''))
jeonbuk_by_ingu15 = jeonbuk15 / int(df_ingu.iloc[12,3].replace(',', ''))
jeonbuk_by_ingu16 = jeonbuk16 / int(df_ingu.iloc[12,4].replace(',', ''))
jeonbuk_by_ingu17 = jeonbuk17 / int(df_ingu.iloc[12,5].replace(',', ''))
jeonbuk_by_ingu18 = jeonbuk18 / int(df_ingu.iloc[12,6].replace(',', ''))
jeonbuk_by_ingu19 = jeonbuk19 / int(df_ingu.iloc[12,7].replace(',', ''))
jeonbuk_by_ingu20 = jeonbuk20 / int(df_ingu.iloc[12,8].replace(',', ''))
jeonbuk_by_ingu21 = jeonbuk21 / int(df_ingu.iloc[12,9].replace(',', ''))
jeonbuk_by_ingu22 = jeonbuk22 / int(df_ingu.iloc[12,10].replace(',', ''))

# %%
jeonnam_by_ingu13 = jeonnam13 / int(df_ingu.iloc[13,1].replace(',', ''))
jeonnam_by_ingu14 = jeonnam14 / int(df_ingu.iloc[13,2].replace(',', ''))
jeonnam_by_ingu15 = jeonnam15 / int(df_ingu.iloc[13,3].replace(',', ''))
jeonnam_by_ingu16 = jeonnam16 / int(df_ingu.iloc[13,4].replace(',', ''))
jeonnam_by_ingu17 = jeonnam17 / int(df_ingu.iloc[13,5].replace(',', ''))
jeonnam_by_ingu18 = jeonnam18 / int(df_ingu.iloc[13,6].replace(',', ''))
jeonnam_by_ingu19 = jeonnam19 / int(df_ingu.iloc[13,7].replace(',', ''))
jeonnam_by_ingu20 = jeonnam20 / int(df_ingu.iloc[13,8].replace(',', ''))
jeonnam_by_ingu21 = jeonnam21 / int(df_ingu.iloc[13,9].replace(',', ''))
jeonnam_by_ingu22 = jeonnam22 / int(df_ingu.iloc[13,10].replace(',', ''))

# %%
gyeongbuk_by_ingu13 = gyeongbuk13 / int(df_ingu.iloc[14,1].replace(',', ''))
gyeongbuk_by_ingu14 = gyeongbuk14 / int(df_ingu.iloc[14,2].replace(',', ''))
gyeongbuk_by_ingu15 = gyeongbuk15 / int(df_ingu.iloc[14,3].replace(',', ''))
gyeongbuk_by_ingu16 = gyeongbuk16 / int(df_ingu.iloc[14,4].replace(',', ''))
gyeongbuk_by_ingu17 = gyeongbuk17 / int(df_ingu.iloc[14,5].replace(',', ''))
gyeongbuk_by_ingu18 = gyeongbuk18 / int(df_ingu.iloc[14,6].replace(',', ''))
gyeongbuk_by_ingu19 = gyeongbuk19 / int(df_ingu.iloc[14,7].replace(',', ''))
gyeongbuk_by_ingu20 = gyeongbuk20 / int(df_ingu.iloc[14,8].replace(',', ''))
gyeongbuk_by_ingu21 = gyeongbuk21 / int(df_ingu.iloc[14,9].replace(',', ''))
gyeongbuk_by_ingu22 = gyeongbuk22 / int(df_ingu.iloc[14,10].replace(',', ''))

# %%
gyeongnam_by_ingu13 = gyeongnam13 / int(df_ingu.iloc[15,1].replace(',', ''))
gyeongnam_by_ingu14 = gyeongnam14 / int(df_ingu.iloc[15,2].replace(',', ''))
gyeongnam_by_ingu15 = gyeongnam15 / int(df_ingu.iloc[15,3].replace(',', ''))
gyeongnam_by_ingu16 = gyeongnam16 / int(df_ingu.iloc[15,4].replace(',', ''))
gyeongnam_by_ingu17 = gyeongnam17 / int(df_ingu.iloc[15,5].replace(',', ''))
gyeongnam_by_ingu18 = gyeongnam18 / int(df_ingu.iloc[15,6].replace(',', ''))
gyeongnam_by_ingu19 = gyeongnam19 / int(df_ingu.iloc[15,7].replace(',', ''))
gyeongnam_by_ingu20 = gyeongnam20 / int(df_ingu.iloc[15,8].replace(',', ''))
gyeongnam_by_ingu21 = gyeongnam21 / int(df_ingu.iloc[15,9].replace(',', ''))
gyeongnam_by_ingu22 = gyeongnam22 / int(df_ingu.iloc[15,10].replace(',', ''))

# %%
labels = ['2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022']
seoul_data = [seoul_by_ingu13, seoul_by_ingu14, seoul_by_ingu15, seoul_by_ingu16, seoul_by_ingu17, 
             seoul_by_ingu18, seoul_by_ingu19, seoul_by_ingu20, seoul_by_ingu21, seoul_by_ingu22]
busan_data = [busan_by_ingu13, busan_by_ingu14, busan_by_ingu15, busan_by_ingu16, busan_by_ingu17, 
             busan_by_ingu18, busan_by_ingu19, busan_by_ingu20, busan_by_ingu21, busan_by_ingu22]
daegu_data = [daegu_by_ingu13, daegu_by_ingu14, daegu_by_ingu15, daegu_by_ingu16, daegu_by_ingu17, 
             daegu_by_ingu18, daegu_by_ingu19, daegu_by_ingu20, daegu_by_ingu21, daegu_by_ingu22]
incheon_data = [incheon_by_ingu13, incheon_by_ingu14, incheon_by_ingu15, incheon_by_ingu16, incheon_by_ingu17, 
             incheon_by_ingu18, incheon_by_ingu19, incheon_by_ingu20, incheon_by_ingu21, incheon_by_ingu22]
gwangju_data = [gwangju_by_ingu13, gwangju_by_ingu14, gwangju_by_ingu15, gwangju_by_ingu16, gwangju_by_ingu17, 
             gwangju_by_ingu18, gwangju_by_ingu19, gwangju_by_ingu20, gwangju_by_ingu21, gwangju_by_ingu22]
daejeon_data = [daejeon_by_ingu13, daejeon_by_ingu14, daejeon_by_ingu15, daejeon_by_ingu16, daejeon_by_ingu17, 
             daejeon_by_ingu18, daejeon_by_ingu19, daejeon_by_ingu20, daejeon_by_ingu21, daejeon_by_ingu22]
ulsan_data = [ulsan_by_ingu13, ulsan_by_ingu14, ulsan_by_ingu15, ulsan_by_ingu16, ulsan_by_ingu17, 
             ulsan_by_ingu18, ulsan_by_ingu19, ulsan_by_ingu20, ulsan_by_ingu21, ulsan_by_ingu22]
sejong_data = [sejong_by_ingu13, sejong_by_ingu14, sejong_by_ingu15, sejong_by_ingu16, sejong_by_ingu17, 
             sejong_by_ingu18, sejong_by_ingu19, sejong_by_ingu20, sejong_by_ingu21, sejong_by_ingu22]
gyeonggi_data = [gyeonggi_by_ingu13, gyeonggi_by_ingu14, gyeonggi_by_ingu15, gyeonggi_by_ingu16, gyeonggi_by_ingu17, 
             gyeonggi_by_ingu18, gyeonggi_by_ingu19, gyeonggi_by_ingu20, gyeonggi_by_ingu21, gyeonggi_by_ingu22]
gangwon_data = [gangwon_by_ingu13, gangwon_by_ingu14, gangwon_by_ingu15, gangwon_by_ingu16, gangwon_by_ingu17, 
             gangwon_by_ingu18, gangwon_by_ingu19, gangwon_by_ingu20, gangwon_by_ingu21, gangwon_by_ingu22]
chungbuk_data = [chungbuk_by_ingu13, chungbuk_by_ingu14, chungbuk_by_ingu15, chungbuk_by_ingu16, chungbuk_by_ingu17, 
             chungbuk_by_ingu18, chungbuk_by_ingu19, chungbuk_by_ingu20, chungbuk_by_ingu21, chungbuk_by_ingu22]
chungnam_data = [chungnam_by_ingu13, chungnam_by_ingu14, chungnam_by_ingu15, chungnam_by_ingu16, chungnam_by_ingu17, 
             chungnam_by_ingu18, chungnam_by_ingu19, chungnam_by_ingu20, chungnam_by_ingu21, chungnam_by_ingu22]
jeonbuk_data = [jeonbuk_by_ingu13, jeonbuk_by_ingu14, jeonbuk_by_ingu15, jeonbuk_by_ingu16, jeonbuk_by_ingu17, 
             jeonbuk_by_ingu18, jeonbuk_by_ingu19, jeonbuk_by_ingu20, jeonbuk_by_ingu21, jeonbuk_by_ingu22]
jeonnam_data = [jeonnam_by_ingu13, jeonnam_by_ingu14, jeonnam_by_ingu15, jeonnam_by_ingu16, jeonnam_by_ingu17, 
             jeonnam_by_ingu18, jeonnam_by_ingu19, jeonnam_by_ingu20, jeonnam_by_ingu21, jeonnam_by_ingu22]
gyeongbuk_data = [gyeongbuk_by_ingu13, gyeongbuk_by_ingu14, gyeongbuk_by_ingu15, gyeongbuk_by_ingu16, gyeongbuk_by_ingu17, 
             gyeongbuk_by_ingu18, gyeongbuk_by_ingu19, gyeongbuk_by_ingu20, gyeongbuk_by_ingu21, gyeongbuk_by_ingu22]
gyeongnam_data = [gyeongnam_by_ingu13, gyeongnam_by_ingu14, gyeongnam_by_ingu15, gyeongnam_by_ingu16, gyeongnam_by_ingu17, 
             gyeongnam_by_ingu18, gyeongnam_by_ingu19, gyeongnam_by_ingu20, gyeongnam_by_ingu21, gyeongnam_by_ingu22]

plt.rcParams["figure.figsize"] = (20, 15)
# 그래프 생성
plt.plot(labels, seoul_data, marker='o', label='서울', color = 'black')
plt.plot(labels, busan_data, marker='o', label='부산', color = 'black')
plt.plot(labels, daegu_data, marker='o', label='대구', color = 'black')
plt.plot(labels, incheon_data, marker='o', label='인천', color = 'black')
plt.plot(labels, gwangju_data, marker='o', label='광주', color = 'black')
plt.plot(labels, daejeon_data, marker='o', label='대전', color = 'black')
plt.plot(labels, ulsan_data, marker='o', label='울산', color = 'black')
plt.plot(labels, sejong_data, marker='o', label='세종', color = 'black')
plt.plot(labels, gyeonggi_data, marker='o', label='경기', linewidth=5)
plt.plot(labels, gangwon_data, marker='o', label='강원', linewidth=5)
plt.plot(labels, chungbuk_data, marker='o', label='충북', color = 'black')
plt.plot(labels, chungnam_data, marker='o', label='충남', linewidth=5)
plt.plot(labels, jeonbuk_data, marker='o', label='전북', color = 'black')
plt.plot(labels, jeonnam_data, marker='o', label='전남', linewidth=5)
plt.plot(labels, gyeongbuk_data, marker='o', label='경북', linewidth=5)
plt.plot(labels, gyeongnam_data, marker='o', label='경남', linewidth=5)

plt.title('Number of Wildfires by Population Density')
plt.xlabel('Year')
plt.ylabel('Number')
plt.legend()
plt.show()

# %%
plt.plot(labels, gyeonggi_data, marker='o', label='경기')
plt.plot(labels, gangwon_data, marker='o', label='강원')
plt.plot(labels, chungnam_data, marker='o', label='충남')
plt.plot(labels, jeonnam_data, marker='o', label='전남')
plt.plot(labels, gyeongbuk_data, marker='o', label='경북')
plt.plot(labels, gyeongnam_data, marker='o', label='경남')

plt.title('인구밀도 대비 화재 발생 횟수')
plt.xlabel('연도')
plt.ylabel('화재 발생 횟수')
plt.legend()
plt.show()
