# %%
import pandas as pd
df = pd.read_csv('4년간SGI.csv', encoding = 'cp949')

# %%
from matplotlib import pyplot as plt
import numpy as np

# %matplotlib inline
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 30
plt.rcParams["figure.figsize"] = (30, 10)

# %%
df.plot(kind = 'line', x = '연도', y = '평균2')
plt.title("평균 SGI")
plt.xlabel("날짜")
plt.ylabel("SGI")
# Out:
# Text(0, 0.5, 'SGI')
