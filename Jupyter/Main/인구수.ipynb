# %%
import pandas as pd
df = pd.read_csv('1722인구data.csv', encoding = 'cp949')

# %%
from matplotlib import pyplot as plt
import numpy as np

# %matplotlib inline
plt.rcParams["font.family"] = 'Malgun Gothic'
plt.rcParams["font.size"] = 30
plt.rcParams["figure.figsize"] = (30, 10)

# %%
data = {
    '연도': [2017, 2018, 2019, 2020, 2021, 2022],
    '강원': [1550142, 1543052, 1541502, 1542840, 1538492, 1536498],
    '경기': [12873895, 13077153, 13239666, 13427014, 13565450, 13589432],
    '경남': [3380404, 3373988, 3362553, 3340216, 3314183, 3280493],
    '경북': [2691706, 2676831, 2665836, 2639422, 2626609, 2600492],
    '전남': [1896424, 1882970, 1868745, 1851549, 1832803, 1817697],
    '충남': [2116770, 2126282, 2123709, 2121029, 2119257, 2123037]
}

df = pd.DataFrame(data)
df.set_index('연도', inplace=True)

df.plot(kind='line')

plt.title('연도에 따른 각 지역별 인구')
plt.xlabel('연도')
plt.ylabel('인구')

plt.show()
